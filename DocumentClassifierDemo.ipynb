# %% [markdown]
# # Document Section Classifier

# %% [markdown]
# Clone and enter repository

# %%
# !git clone https://github.com/KMielnik/DocumentSectionClassifier
# %cd DocumentSectionClassifier

# %% [markdown]
# Install dependencies

# %%
# !pip install imgaug==0.2.6
# !pip install git+https://github.com/dhlab-epfl/dhSegment
# !pip install tensorflow==1.13.1
# !pip install tensorflow-gpu==1.13.1

# %% [markdown]
# Download model
#
# (This is the place where you can use your own trained model instead, just upload it to the empty model folder)

# %%
# !gdown https://drive.google.com/uc?id=1XBOpJSczHxDNstFL69LlKN4ET64HON9t
# !unzip model.zip
# !rm model.zip

# %% [markdown]
# Load your trained model

# %%
from classifier import load_model

m, s = load_model()

# %% [markdown]
# Process your documents (by default all from the input catalog, you can select other catalogs / enable just the mask creation in parameters)

# %%
from classifier import process_all_documents

process_all_documents(model= m)

# %% [markdown]
# Close the session opened in loading model step if you are done with document processing

# %%
s.close()
